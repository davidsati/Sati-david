# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from statistics import mean, variance, stdev, mode, median
import pandas

# %%
data = pd.read_csv("cven1.csv")
africa_array=["Algeria", "Angola", "Benin", "Botswana", "Burkina", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Comoros", "Congo", "Congo, Democratic Republic of", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Swaziland", "Tanzania", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"]


data=data[data['COUNTRY'].isin(africa_array)]
data.set_index('COUNTRY', inplace=True)

data=data.sort_values('2009')



data
# Out:
#                              2009   2010   2011     2012     2013  2014  \
# COUNTRY
# Mauritania                  2.000   19.0   19.0    12.00    13.00  88.0
# Eritrea                     3.916    7.9    7.9     7.93     7.93  88.0
# Central African Republic    4.700    9.7    9.7     9.74     9.73  88.0
# Chad                        9.600   17.2   17.2    17.90    17.30  88.0
# Malawi                     11.080   21.0   21.0    21.00    23.00  88.0
# Egypt                      14.200   19.0   19.0    11.00    13.00  88.0
# Sudan                      18.000   32.5   32.5    32.10    32.30  88.0
# Niger                      31.700   32.4   32.4    32.30    32.30  88.0
# Angola                     32.000   21.0   21.0    21.00    23.00  88.0
# Cape Verde                 37.700   29.9   29.9    29.30    29.30  88.0
# Botswana                   41.000   37.0   37.0    34.00    33.00  88.0
# Libya                      43.000   47.0   47.0    44.00    43.00  88.0
# Senegal                    53.100   32.0   32.0    35.00    33.00  88.0
# Morocco                    58.800   32.3   32.3    32.50    32.30  88.0
# Mozambique                 60.400   89.7   89.7    89.60    89.30  88.0
# Mauritius                  65.000   70.0   70.0    76.00    73.00  88.0
# Tunisia                    65.000   80.0   80.0    86.00    83.00  88.0
# Mali                       73.700   40.2   40.2    40.70    40.30  88.0
# Gambia                     77.000   57.0   57.0    57.00    53.00  88.0
# Namibia                    80.200   80.2   80.2    80.80    80.30  88.0
# Djibouti                   81.400   85.0   85.0    85.80    85.30  88.0
# Guinea-Bissau              86.000  114.4  114.4  1148.00  1143.00  88.0
# Lesotho                    88.000  100.2  100.2  1008.00  1003.00  88.0
# Algeria                    90.000   95.0  145.0   154.00   152.00  88.9
# Sao Tome and Principe      94.000   94.0   94.0    99.00    93.00  88.0
# South Sudan                96.200  134.0  134.0  1349.00  1343.00  88.0
# South Africa               99.300   89.3   89.3    89.90    89.30  88.0
# Nigeria                   102.800  124.8  124.8  1241.00  1243.00  88.0
# Rwanda                    133.000  133.0  133.0  1331.00  1333.00  88.0
# Uganda                    141.100  180.9  180.9  1801.00  1803.00  88.0
# Zambia                    141.100  156.1  156.1  1561.00  1563.00  88.0
# Sierra Leone              149.000  124.0  124.0  1241.00  1243.00  88.0
# Cameroon                  150.000  138.3  138.3  1381.00  1383.00  88.0
# Guinea                    172.900  132.2  132.2  1321.00  1323.00  88.0
# Ethiopia                  177.800  198.2  198.2  1981.00  1983.00  88.0
# Liberia                   182.000  154.7  154.7  1541.00  1543.00  88.0
# Comoros                   187.600  200.3  200.3  2001.00  2003.00  88.0
# Madagascar                200.000  179.0  179.0  1792.00  1793.00  88.0
# Zimbabwe                  232.400  250.7  250.7  2502.00  2503.00  88.0
# Togo                      236.400  188.6  188.6  1882.00  1883.00  88.0
# Ghana                     237.700  250.4  250.4  2502.00  2503.00  88.0
# Seychelles                241.900  280.1  280.1  2802.00  2803.00  88.0
# Congo                     243.100  231.2  231.2  2312.00  2313.00  88.0
# Tanzania                  255.300  234.0  234.0  2342.00  2343.00  88.0
# Burundi                   256.800  243.9  243.9  2432.00  2433.00  88.0
# Gabon                     274.100  280.3  280.3  2802.00  2803.00  88.0
# Somalia                   283.300  290.7  290.7  2902.00  2903.00  88.0
#
#                              2015   2016     2017     2018      2019
# COUNTRY
# Mauritania                  15.00  178.0    17.00    18.00    12.000
# Eritrea                      7.95  178.0     7.97     7.98     7.916
# Central African Republic     9.75  178.0     9.77     9.78     9.770
# Chad                        17.50  178.0    17.70    17.80    17.600
# Malawi                      25.00  178.0    27.00    28.00   208.000
# Egypt                       15.00  178.0    17.00    18.00    12.000
# Sudan                       32.50  178.0    32.70    32.80    32.800
# Niger                       32.50  178.0    32.70    32.80    32.700
# Angola                      25.00  178.0    27.00    28.00    22.000
# Cape Verde                  29.50  178.0    29.70    29.80    29.700
# Botswana                    35.00  178.0    37.00    38.00    31.000
# Libya                       45.00  178.0    47.00    48.00    43.000
# Senegal                     35.00  178.0    37.00    38.00    31.000
# Morocco                     32.50  178.0    32.70    32.80    32.800
# Mozambique                  89.50  178.0    89.70    89.80    89.400
# Mauritius                   75.00  178.0    77.00    78.00    75.000
# Tunisia                     85.00  178.0    87.00    88.00    85.000
# Mali                        40.50  178.0    40.70    40.80    40.700
# Gambia                      55.00  178.0    57.00    58.00    57.000
# Namibia                     80.50  178.0    80.70    80.80    80.200
# Djibouti                    85.50  178.0    85.70    85.80    85.400
# Guinea-Bissau             1145.00  178.0  1147.00  1148.00  1146.000
# Lesotho                   1005.00  178.0  1007.00  1008.00  1008.000
# Algeria                    210.00  178.9    97.00    98.00    90.000
# Sao Tome and Principe       95.00  178.0    97.00    98.00    94.000
# South Sudan               1345.00  178.0  1347.00  1348.00  1342.000
# South Africa                89.50  178.0    89.70    89.80    89.300
# Nigeria                   1245.00  178.0  1247.00  1248.00   124.800
# Rwanda                    1335.00  178.0  1337.00  1338.00  1333.000
# Uganda                    1805.00  178.0  1807.00  1808.00   180.100
# Zambia                    1565.00  178.0  1567.00  1568.00   156.100
# Sierra Leone              1245.00  178.0  1247.00  1248.00  1249.000
# Cameroon                  1385.00  178.0  1387.00  1388.00  1380.000
# Guinea                    1325.00  178.0  1327.00  1328.00   132.900
# Ethiopia                  1985.00  178.0  1987.00  1988.00   198.800
# Liberia                   1545.00  178.0  1547.00  1548.00  1542.000
# Comoros                   2005.00  178.0  2007.00  2008.00   200.600
# Madagascar                1795.00  178.0  1797.00  1798.00  1790.000
# Zimbabwe                  2505.00  178.0  2507.00  2508.00   250.400
# Togo                      1885.00  178.0  1887.00  1888.00   188.400
# Ghana                     2505.00  178.0  2507.00  2508.00   250.700
# Seychelles                2805.00  178.0  2807.00  2808.00   280.900
# Congo                     2315.00  178.0  2317.00  2318.00   231.100
# Tanzania                  2345.00  178.0  2347.00  2348.00   234.300
# Burundi                   2435.00  178.0  2437.00  2438.00   243.800
# Gabon                     2805.00  178.0  2807.00  2808.00   280.100
# Somalia                   2905.00  178.0  2907.00  2908.00   290.300

# %%
for year in range(2009, 2020):
    data.plot.bar(y=str(year),figsize=(12,12),title=str(year))
    plt.figure(figsize=(50,50))
    #plt.title("a graph of adult literacy rate in africa")
    #plt.xlabel("country")
    #plt.ylabel("percentage")
    plt.show()

# %%
vertical=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
data[vertical].mean()

# %%
data[vertical].std()

# %%
data[vertical].var()

# %%
data[vertical].mode

# %%
data[vertical].median

# %%
data.groupby('COUNTRY').median().plot.bar(stacked=True)
plt.title('Median')
plt.show()

# %%
data.groupby('COUNTRY').median().plot.bar(stacked=True)
plt.title('Median')
plt.show()

# %%
or year in range(2010,2020):
    data.plot.hist(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))
# Out:
#   File "<ipython-input-18-621dbde7a150>", line 1
#     or year in range(2010,2020):
#     ^
# SyntaxError: invalid syntax

# %%
for year in range(2010,2020):
    data.plot.line(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.kde(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))
